# %%
import pandas as pd
import textstat
from tqdm import tqdm

textstat.set_lang('en')

# %%
csv_filename = "all_utterances.json"
data_df = pd.read_json(csv_filename)

# %%
kf_total = []
spache_total = []

for file in tqdm(range(len(data_df))):
    kf_ease = []
    spache_ease = []
    for sentence in data_df['plain_utterances'][file]:
        clean_sentence = sentence.replace("POSTCLITIC", "")
        kf_ease.append(textstat.flesch_reading_ease(clean_sentence))
        spache_ease.append(textstat.spache_readability(clean_sentence))
    kf_total.append(kf_ease)
    spache_total.append(spache_ease)
# Out:
# 100%|██████████| 147/147 [00:00<00:00, 1615.15it/s]

# %%
utterance_strs = [" ".join(u) if isinstance(u, (list, tuple)) else (u or "") for u in data_df['plain_utterances']]
data_df['plain_utterances_str'] = utterance_strs

# %%
data_df['kf_ease'] = kf_total
data_df['spache_ease'] = spache_total
data_df['kf_ease_avg'] = [sum(x)/len(x) for x in kf_total]
data_df['kf_ease_total_avg'] = [textstat.flesch_reading_ease(x) for x in data_df['plain_utterances_str']]
data_df['spache_avg'] = [sum(x)/len(x) for x in spache_total]
data_df['spache_ease_total_avg'] = [textstat.spache_readability(x) for x in data_df['plain_utterances_str']]

# %%
data_df
# Out:
#                             dataset      filename            age languages  \
# 0    English_Bilingual_Grade2_Audio  11221425.cha    [[8, 3, 0]]     [eng]
# 1    English_Bilingual_Grade2_Audio  11222222.cha    [[8, 2, 0]]     [eng]
# 2    English_Bilingual_Grade2_Audio  11222306.cha    [[7, 9, 0]]     [eng]
# 3    English_Bilingual_Grade2_Audio  12122227.cha    [[8, 5, 0]]     [eng]
# 4    English_Bilingual_Grade2_Audio  12222013.cha    [[8, 0, 0]]     [eng]
# ..                              ...           ...            ...       ...
# 142      English_Monolingual_Grade5  32332152.cha   [[11, 0, 0]]     [eng]
# 143      English_Monolingual_Grade5  32332266.cha  [[11, 11, 0]]     [eng]
# 144      English_Monolingual_Grade5  32332283.cha   [[11, 3, 0]]     [eng]
# 145      English_Monolingual_Grade5  42331438.cha   [[11, 0, 0]]     [eng]
# 146      English_Monolingual_Grade5  42332310.cha   [[11, 2, 0]]     [eng]
#
#      is_bilingual                                   plain_utterances  \
# 0            True  [the boy and the dog were looking at the frog ...
# 1            True  [the boy went to sleep ., and the frog jumped ...
# 2            True  [one night the boy and the dog were looking at...
# 3            True  [the dog and the boy is sleeping ., the frog i...
# 4            True  [there was this boy ., he got a a pet that's P...
# ..            ...                                                ...
# 142         False  [a boy his dog and his pet frog are in a room ...
# 143         False  [the boy is watching his dog looking at the fr...
# 144         False  [the dog is looking into a jar that has a frog...
# 145         False  [the boy and his dog are looking at the frog ....
# 146         False  [one day a boy found a frog and brought it hom...
#
#                                   plain_utterances_str  \
# 0    the boy and the dog were looking at the frog ....
# 1    the boy went to sleep . and the frog jumped ou...
# 2    one night the boy and the dog were looking at ...
# 3    the dog and the boy is sleeping . the frog is ...
# 4    there was this boy . he got a a pet that's POS...
# ..                                                 ...
# 142  a boy his dog and his pet frog are in a room ....
# 143  the boy is watching his dog looking at the fro...
# 144  the dog is looking into a jar that has a frog ...
# 145  the boy and his dog are looking at the frog . ...
# 146  one day a boy found a frog and brought it home...
#
#                                                kf_ease  \
# 0    [103.625, 115.13000000000002, 103.54, 116.1450...
# 1    [117.16000000000003, 103.70000000000002, 103.0...
# 2    [103.00500000000001, 103.04428571428575, 103.7...
# 3    [103.04428571428575, 92.965, 95.165, 92.965, 9...
# 4    [118.17500000000001, 111.07000000000002, 90.99...
# ..                                                 ...
# 142  [110.055, 117.16000000000003, 117.160000000000...
# 143  [95.165, 103.04428571428575, 103.7000000000000...
# 144  [84.8057142857143, 100.24000000000002, 95.42, ...
# 145  [103.625, 101.37000000000002, 115.130000000000...
# 146  [111.07000000000002, 103.04428571428575, 100.2...
#
#                                            spache_ease  kf_ease_avg  \
# 0    [3.1089999999999995, 1.8259999999999998, 1.966...   102.705322
# 1    [1.544, 2.1079999999999997, 3.0545714285714287...   108.029452
# 2    [3.2476666666666665, 3.0545714285714287, 2.107...   103.385723
# 3    [3.0545714285714287, 1.9669999999999999, 2.248...   103.648944
# 4    [1.403, 2.3899999999999997, 4.128666666666667,...   107.743664
# ..                                                 ...          ...
# 142  [2.5309999999999997, 1.544, 1.544, 1.825999999...   111.244307
# 143  [3.969, 3.0545714285714287, 3.0635555555555554...    99.541831
# 144  [4.619047619047619, 1.544, 3.6325, 2.812999999...   100.135832
# 145  [3.1089999999999995, 3.527333333333333, 1.8259...   104.998838
# 146  [2.3899999999999997, 1.8259999999999998, 1.544...    99.079020
#
#      kf_ease_total_avg  spache_avg  spache_ease_total_avg
# 0           100.527452    2.341721               2.591364
# 1           106.310333    2.044024               2.093089
# 2           100.953344    2.438240               2.554833
# 3            99.268321    1.829590               2.119970
# 4           105.529574    1.771739               1.964895
# ..                 ...         ...                    ...
# 142         108.345523    1.954626               2.030804
# 143          97.166232    2.778196               2.889269
# 144          96.248290    2.773217               2.992515
# 145         100.765510    2.034604               2.335686
# 146          96.506451    2.714508               2.932054
#
# [147 rows x 13 columns]

# %%
order = ['dataset', 'filename', 'kf_ease_avg', 'spache_avg', 'kf_ease', 'spache_ease', 'kf_ease_total_avg',  'spache_ease_total_avg', 'plain_utterances', 'plain_utterances_str']
data_df[order].to_csv('Score_df.csv', index=False)
